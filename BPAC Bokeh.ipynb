# %% [markdown]
# # Newport Pedestrian Safety Survey - 2014
# This notebook visualizes the results of the 2014 pedestrian safety survey, which asked responents to rate 25 intersections in the City of Newport, RI either "Safe", "Unsafe" or "Don't Know".  The "Don't Know" category is ambiguous in that it covers the situiation where the respondent isn't familiar with the intersection in question, as well as the situation where the respondent has had both safe and unsafe experiences, and cannot classify as one or the other.  Because of this, the "Don't Know" responses were discarded from the safety scaling.

# %%
import geopandas as gpd
import json

import pandas as pd

from bokeh.plotting import figure, output_notebook, show
from bokeh.models import GeoJSONDataSource, ColorBar, HoverTool, Range1d
from bokeh.tile_providers import STAMEN_TONER, CARTODBPOSITRON
from bokeh.models.mappers import LinearColorMapper
from bokeh.palettes import Spectral6

# %%
# load bokeh
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d919070c-6360-47a3-84ea-d6400ea45295">Loading BokehJS ...</span>
#     </div>

# %%
gdf = gpd.read_file('./pedestrian-safety-2014/pedestrian-safety-2014.shp')
survey = pd.read_csv('Newport Pedestrian Safety Survey - May 2014 cleaned.csv')

# %%
# drop unused columns
slim_survey = survey.drop(['Collector ID', 'Start Date', 'End Date', 'Comment/Explanation'], axis=1)

# make the columns line up with intersection ids
column_names = [
    'Respondent ID',
                1,1,1,
                2,2,2,
                3,3,3,
                4,4,4,
                5,5,5,
                6,6,6,
                7,7,7,
                8,8,8,
                9,9,9,
                10,10,10,
                11,11,11,
                12,12,12,
                13,13,13,
                14,14,14,
                15,15,15,
                16,16,16,
                17,17,17,
                18,18,18,
                19,19,19,
                20,20,20,
                21,21,21,
                22,22,22,
                23,23,23,
                24,24,24,
                25,25,25
                ]
slim_survey.columns = column_names

# add geodataframe columns
gdf['Safe']=""
gdf['Unsafe']=""
gdf["I don't know."]=""
gdf["score"]=""

# %%
# build geodataframe of aggregate data, and calculate safety score
for i in range(0,25):
    counts = slim_survey[i+1].melt().value.value_counts(sort=False)
    gdf['score'].iloc[i] = counts['Safe']/(counts['Safe']+counts['Unsafe'])
    gdf['Safe'].iloc[i] = counts['Safe'].astype('float')
    gdf['Unsafe'].iloc[i] = counts['Unsafe'].astype('float')
    gdf["I don't know."].iloc[i] = counts["I don't know."].astype('float')
# Out:
# C:\Miniconda3\envs\geospatial\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# create the GeoJSONDataSource
geosource = GeoJSONDataSource(geojson=gdf.to_crs(epsg=3857).to_json())

# %% [markdown]
# # Process the data
# The score given each crossing is calculated as the ratio of "Safe" responses to total "Safe" and "Unsafe" responses. The plot shows crossings with higher safety scores as green, and low safety scores as red.

# %%
# define tooltip information
hover = HoverTool(tooltips=[
    ("Intersection", "@id"),
    ("Safe", "@Safe"),
    ("Unsafe", "@Unsafe"),
    ("Score", "@score"),
])

# define color map for plot, swapped low-high for numbers closer to 1 to be green
cmap = LinearColorMapper(palette = Spectral6, low=1, high=0)

# set plotting ranges
minx, miny, maxx, maxy = gdf.to_crs(epsg=3857).total_bounds
mercator_x_extent = dict(start=minx-25, end=maxx+25, bounds=None)
mercator_y_extent = dict(start=miny-25, end=maxy+25, bounds=None)
x_range = Range1d(**mercator_x_extent)
y_range = Range1d(**mercator_y_extent)

# build plot
p = figure(tools=["wheel_zoom,box_zoom,pan", hover], x_range=x_range, y_range=y_range)
p.add_tile(CARTODBPOSITRON)
p.circle(x='x', y='y', size=12, alpha=0.9, source=geosource, fill_color={'field': 'score', 'transform':cmap}, line_color=None)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="144828b0-8144-4fa7-8c1d-e13e8b861a7d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("144828b0-8144-4fa7-8c1d-e13e8b861a7d");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("144828b0-8144-4fa7-8c1d-e13e8b861a7d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '144828b0-8144-4fa7-8c1d-e13e8b861a7d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"63bbd180-47cc-4acb-8c8c-13bad6a73009":{"roots":{"references":[{"attributes":{"below":[{"id":"ebfd5478-d82f-4ee9-b5c2-31605261d4e4","type":"LinearAxis"}],"left":[{"id":"64caae6c-6993-4e50-9a16-6d373f0f9af7","type":"LinearAxis"}],"renderers":[{"id":"ebfd5478-d82f-4ee9-b5c2-31605261d4e4","type":"LinearAxis"},{"id":"e846ec3b-03e7-4054-bcfc-0846849ffeb7","type":"Grid"},{"id":"64caae6c-6993-4e50-9a16-6d373f0f9af7","type":"LinearAxis"},{"id":"5274a3d2-5f55-4f7a-995b-5c1c0af8c712","type":"Grid"},{"id":"4dd28b80-1781-495b-bd21-b8a67647a043","type":"BoxAnnotation"},{"id":"ba9b463a-4aae-4818-bacb-50b03efbaf95","type":"TileRenderer"},{"id":"e694466c-1873-4db0-9c8b-1053f6b203a7","type":"GlyphRenderer"}],"title":{"id":"7129bd30-c3aa-4d99-911a-0302646dfed6","type":"Title"},"toolbar":{"id":"f1a082ed-2da0-4136-a81e-2427ed161c26","type":"Toolbar"},"x_range":{"id":"7ac039de-e188-4e9d-8353-e7fc764b72c1","type":"Range1d"},"x_scale":{"id":"6d473b86-91b0-4907-a8fd-c0c96e6e5807","type":"LinearScale"},"y_range":{"id":"096850e6-01d6-4683-a7fa-6f8a705c3851","type":"Range1d"},"y_scale":{"id":"1581dd52-5d8c-4b3d-86e4-9f5c84515a69","type":"LinearScale"}},"id":"f5b2dd59-e070-4f9c-a5f5-3c329089e1e1","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1581dd52-5d8c-4b3d-86e4-9f5c84515a69","type":"LinearScale"},{"attributes":{"formatter":{"id":"e3487cbc-e4da-439e-b48a-bc7f98513757","type":"BasicTickFormatter"},"plot":{"id":"f5b2dd59-e070-4f9c-a5f5-3c329089e1e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"eeae0f67-c278-4782-ac73-20e8bd568237","type":"BasicTicker"}},"id":"ebfd5478-d82f-4ee9-b5c2-31605261d4e4","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"score","transform":{"id":"e33d1dc3-b702-40cf-b6b6-67de4420928d","type":"LinearColorMapper"}},"line_alpha":{"value":0.9},"line_color":{"value":null},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"9852147b-faa1-4b31-b2a9-5cc7d1752a1e","type":"Circle"},{"attributes":{},"id":"6d473b86-91b0-4907-a8fd-c0c96e6e5807","type":"LinearScale"},{"attributes":{"formatter":{"id":"c4e71996-3b8e-4d3f-9065-dbc7153a3f08","type":"BasicTickFormatter"},"plot":{"id":"f5b2dd59-e070-4f9c-a5f5-3c329089e1e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"ecf46a23-622f-452d-95fd-731773fc21dc","type":"BasicTicker"}},"id":"64caae6c-6993-4e50-9a16-6d373f0f9af7","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b0cd9b39-4558-4bf6-99c4-90a034303c28","type":"HoverTool"},{"id":"7c5f6a44-8174-47ab-afba-d07bfbc29f6e","type":"WheelZoomTool"},{"id":"59a020c8-90a8-4c7e-b6f9-12df1674a1b0","type":"BoxZoomTool"},{"id":"7d79d38e-b6be-450a-936d-a839093c007a","type":"PanTool"}]},"id":"f1a082ed-2da0-4136-a81e-2427ed161c26","type":"Toolbar"},{"attributes":{},"id":"e3487cbc-e4da-439e-b48a-bc7f98513757","type":"BasicTickFormatter"},{"attributes":{"attribution":"&copy; <a href=\"http://www.openstreetmap.org/copyright\">OpenStreetMap</a> contributors,&copy; <a href=\"https://cartodb.com/attributions\">CartoDB</a>","url":"http://tiles.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png"},"id":"d260be67-448c-4e9e-b6b2-73c952d4d1e0","type":"WMTSTileSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4dd28b80-1781-495b-bd21-b8a67647a043","type":"BoxAnnotation"},{"attributes":{"high":0,"low":1,"palette":["#3288bd","#99d594","#e6f598","#fee08b","#fc8d59","#d53e4f"]},"id":"e33d1dc3-b702-40cf-b6b6-67de4420928d","type":"LinearColorMapper"},{"attributes":{},"id":"7d79d38e-b6be-450a-936d-a839093c007a","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"7129bd30-c3aa-4d99-911a-0302646dfed6" ...
